# %% [markdown]
# Melanger le taquin :
# ============

# %%
from tkinter import *
from random import shuffle
CANVAS_SIDE=400
NB_SQUARES=4
R=CANVAS_SIDE//NB_SQUARES

def fill_board(cnv, board):
    for i in range(NB_SQUARES):
        for j in range(NB_SQUARES):
            v=board[i][j]
            if not i==j==NB_SQUARES-1:
                cnv.create_rectangle(j*R, i*R, (1+j)*R, (1+i)*R, fill="lavender",tag="taquin")
                cnv.create_text(j*R+R//2, i*R+R//2, text=v,  font=('courier', CANVAS_SIDE//10, 'bold'),tag="taquin")

def shuffle_board(cnv):
    cnv.delete("taquin")
    board=[[NB_SQUARES*lin+1+col for col in range(NB_SQUARES)] for lin in range(NB_SQUARES)]
    shuffle(board)    
    for i in range(NB_SQUARES):
        for j in range(NB_SQUARES):
            v=board[i][j]
            if not i==j==NB_SQUARES-1:
                cnv.create_rectangle(j*R, i*R, (1+j)*R, (1+i)*R, fill="lavender",tag="taquin")
                cnv.create_text(j*R+R//2, i*R+R//2, text=v,  font=('courier', CANVAS_SIDE//10, 'bold'),tag="taquin")

def draw():
    master=Tk()
    cnv=Canvas(master, width=CANVAS_SIDE, height=CANVAS_SIDE, bg='ivory')
    cnv.pack()
    board=[[NB_SQUARES*lin+1+col for col in range(NB_SQUARES)] for lin in range(NB_SQUARES)]
    fill_board(cnv, board)
    b=Button(master, text="Play", command=lambda: shuffle_board(cnv), width=5)
    b.pack(padx=50, pady=20)
    master.mainloop()
    
draw()

# %% [markdown]
# Automate de l'arbre
# ============

# %%
from random import sample
from random import randrange
from tkinter import Tk, Canvas

def random_forest(p, n):
    units=[(line,col) for col in range(n) for line in range(n)]
    ntrees=int(n**2*p)
    trees=sample(units,ntrees)
    states=[[0]*n for _ in range(n)]
    for (i,j) in trees:
        states[i][j]=1    
    return states
                
def fill(cnv, states, unit):
    ids=[]
    n=len(states)
    for line in range(n):
        for col in range(n):
            A=(unit*col, unit*line)
            B=(unit*(col+1), unit*(line+1))
            state=states[line][col]
            color=["ivory", "lime green", "red", "gray75"][state]
            id_=cnv.create_rectangle(A, B, fill=color, outline='')
            ids.append(id_)
    return ids
            
def brulez(ids):
    x=randrange(50)
    y=randrange(50)
    A=(unit*x, unit*y)
    B=(unit*(x+1), unit*(y+1))
    idd=cnv.create_rectangle(A, B, fill="red", outline='',tag="arbre")
    while idd!=ids[i]:
        cnv.delete("arbre")
        idd=cnv.create_rectangle(A, B, fill="red", outline='',tag="arbre")

p=0.2
n=50

root = Tk()
unit=10
side=unit*n
cnv = Canvas(root, width=unit*n, height=unit*n, background="ivory")
cnv.pack(padx=10, pady=10)
states=random_forest(p,n)
fill(cnv, states, unit)
b=fill(cnv, states, unit)
lbl=Label(root, text=(((unit*n)**2)*p)/100, font='Arial 30 bold')
lbl.pack(padx=15, pady=15)
b=Button(root, text="Play",command=lambda: brulez(b), width=5)
b.pack(padx=50, pady=20)
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-43-7c10935ac3df>", line 51, in <lambda>
#     b=Button(root, text="Play",command=lambda: brulez(b), width=5)
#   File "<ipython-input-43-7c10935ac3df>", line 33, in brulez
#     for i in range(len(ids)):
# TypeError: object of type 'Button' has no len()
